# %% [markdown]
# <a href="https://colab.research.google.com/github/Misha-private/Demo-repo/blob/main/MGBF_input_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import MGBF dataset and try to get data from it
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Datasets/MGBF_features.csv')
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#        Tmax      Tmin      umax      umin      vmax      vmin      qmax  \
# 0  0.860626 -0.584259  5.698839 -3.247985  2.960909 -3.492116  0.000477
# 1  0.923737 -0.696594  3.315393 -1.868390  2.536789 -2.216322  0.000563
# 2  0.715912 -0.416290  4.907865 -2.375417  3.071500 -2.785084  0.000445
# 3  0.850525 -0.851349  5.925714 -3.385446  3.062413 -3.690240  0.000418
# 4  0.873657 -0.861298  2.749681 -1.840218  2.330765 -2.251137  0.000467
#
#        qmin
# 0 -0.000224
# 1 -0.000253
# 2 -0.000167
# 3 -0.000240
# 4 -0.000268

# %%
df_a = df
df_a
df.dtypes
df_a.dtypes
df_a.keys()
df_a.describe()
df_a.shape
df_a.describe(include='all')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tmax    52 non-null     float64
#  1   Tmin    52 non-null     float64
#  2   umax    52 non-null     float64
#  3   umin    52 non-null     float64
#  4   vmax    52 non-null     float64
#  5   vmin    52 non-null     float64
#  6   qmax    52 non-null     float64
#  7   qmin    52 non-null     float64
# dtypes: float64(8)
# memory usage: 3.4 KB

# %%
df.columns
# Out:
# Index(['Tmax', 'Tmin', 'umax', 'umin', 'vmax', 'vmin', 'qmax', 'qmin'], dtype='object')

# %%
df['Tmax']
# Out:
# 0     0.860626
# 1     0.923737
# 2     0.715912
# 3     0.850525
# 4     0.873657
# 5     0.863953
# 6     0.895691
# 7     0.891632
# 8     0.933197
# 9     0.861603
# 10    0.727753
# 11    0.922790
# 12    0.884552
# 13    0.676880
# 14    0.898804
# 15    0.850677
# 16    0.902008
# 17    0.919891
# 18    0.845642
# 19    0.784637
# 20    0.884949
# 21    0.937317
# 22    0.882416
# 23    0.863922
# 24    0.858307
# 25    0.818085
# 26    0.931366
# 27    0.896118
# 28    0.869049
# 29    0.686798
# 30    0.940918
# 31    0.941681
# 32    0.928925
# 33    0.913971
# 34    0.909668
# 35    0.837311
# 36    0.828400
# 37    0.594879
# 38    0.820557
# 39    0.836884
# 40    0.645966
# 41    0.732117
# 42    0.876648
# 43    0.870911
# 44    0.855164
# 45    0.884521
# 46    0.689270
# 47    0.880096
# 48    0.756958
# 49    0.872284
# 50    0.637512
# 51    0.904633
# Name: Tmax, dtype: float64

# %%
df_a[['Tmax','Tmin']]
# Out:
#         Tmax      Tmin
# 0   0.860626 -0.584259
# 1   0.923737 -0.696594
# 2   0.715912 -0.416290
# 3   0.850525 -0.851349
# 4   0.873657 -0.861298
# 5   0.863953 -0.798340
# 6   0.895691 -1.011047
# 7   0.891632 -0.771759
# 8   0.933197 -1.232208
# 9   0.861603 -0.739990
# 10  0.727753 -0.473572
# 11  0.922790 -0.801971
# 12  0.884552 -0.770630
# 13  0.676880 -0.454712
# 14  0.898804 -0.844788
# 15  0.850677 -0.781189
# 16  0.902008 -0.657562
# 17  0.919891 -0.673431
# 18  0.845642 -0.717651
# 19  0.784637 -0.433411
# 20  0.884949 -0.632294
# 21  0.937317 -0.857666
# 22  0.882416 -0.892609
# 23  0.863922 -1.201660
# 24  0.858307 -0.600525
# 25  0.818085 -0.592224
# 26  0.931366 -0.894196
# 27  0.896118 -0.872314
# 28  0.869049 -0.750183
# 29  0.686798 -0.378113
# 30  0.940918 -1.186310
# 31  0.941681 -1.027771
# 32  0.928925 -1.175446
# 33  0.913971 -0.688202
# 34  0.909668 -0.770294
# 35  0.837311 -0.691650
# 36  0.828400 -0.704437
# 37  0.594879 -0.273285
# 38  0.820557 -0.560333
# ...

# %%
df_a[['Tmin', 'Tmax']].head()
# Out:
#        Tmin      Tmax
# 0 -0.584259  0.860626
# 1 -0.696594  0.923737
# 2 -0.416290  0.715912
# 3 -0.851349  0.850525
# 4 -0.861298  0.873657

# %%
df.keys()
# Out:
# Index(['Tmax', 'Tmin', 'umax', 'umin', 'vmax', 'vmin', 'qmax', 'qmin'], dtype='object')

# %%
df_a[3:6]
# Out:
#        Tmax      Tmin      umax      umin      vmax      vmin      qmax  \
# 3  0.850525 -0.851349  5.925714 -3.385446  3.062413 -3.690240  0.000418
# 4  0.873657 -0.861298  2.749681 -1.840218  2.330765 -2.251137  0.000467
# 5  0.863953 -0.798340  5.828377 -3.151708  3.263429 -3.148530  0.000486
#
#        qmin
# 3 -0.000240
# 4 -0.000268
# 5 -0.000229

# %%
df_a[5:6]['Tmin']
# Out:
# 5   -0.79834
# Name: Tmin, dtype: float64

# %%
a = df_a[5:6]['Tmax']
print(a)
a.values
# Out:
# 5    0.863953
# Name: Tmax, dtype: float64
# array([0.86395264])

# %%
import torch
import numpy as np

b = a.values
c = b*2.5
c
# Out:
# array([2.1598816])

# %%
k = (len(df_a['Tmin']))
for k in range(k):
  print(df_a[k:k+1]['Tmin'])
# Out:
# 0   -0.584259
# Name: Tmin, dtype: float64
# 1   -0.696594
# Name: Tmin, dtype: float64
# 2   -0.41629
# Name: Tmin, dtype: float64
# 3   -0.851349
# Name: Tmin, dtype: float64
# 4   -0.861298
# Name: Tmin, dtype: float64
# 5   -0.79834
# Name: Tmin, dtype: float64
# 6   -1.011047
# Name: Tmin, dtype: float64
# 7   -0.771759
# Name: Tmin, dtype: float64
# 8   -1.232208
# Name: Tmin, dtype: float64
# 9   -0.73999
# Name: Tmin, dtype: float64
# 10   -0.473572
# Name: Tmin, dtype: float64
# 11   -0.801971
# Name: Tmin, dtype: float64
# 12   -0.77063
# Name: Tmin, dtype: float64
# 13   -0.454712
# Name: Tmin, dtype: float64
# 14   -0.844788
# Name: Tmin, dtype: float64
# 15   -0.781189
# Name: Tmin, dtype: float64
# 16   -0.657562
# Name: Tmin, dtype: float64
# 17   -0.673431
# Name: Tmin, dtype: float64
# 18   -0.717651
# Name: Tmin, dtype: float64
# 19   -0.433411
# Name: Tmin, dtype: float64
# 20   -0.632294
# Name: Tmin, dtype: float64
# 21   -0.857666
# Name: Tmin, dtype: float64
# ...
