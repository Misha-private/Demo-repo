# %% [markdown]
# <a href="https://colab.research.google.com/github/Misha-private/Demo-repo/blob/main/KAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://kindxiaoming.github.io/pykan/intro.html

# %% [markdown]
# 1. Install KAN

# %%
# !pip install pykan

# %% [markdown]
# 2. Initialize KAN

# %% [markdown]
# 3. Create Dataset

# %%
from kan import *
# create a KAN: 2D inputs, 1D ouput and 5 hiddnen neurons, cubic spline (k=3)
model = KAN(width=[2, 5, 1], grid = 5, k=3, seed=0)

# %%
# create dataset f(x,y)= exp(sin(pi*x)+y^2)
f = lambda x: torch.exp(torch.sin(torch.pi*x[:,[0]]) + x[:,[1]]**2)
dataset = create_dataset(f, n_var=2)
dataset['train_input'].shape, dataset['train_label'].shape
# Out:
# (torch.Size([1000, 2]), torch.Size([1000, 1]))

# %% [markdown]
# 4. Plot KAN

# %%
# Plot KAN at initialization
model(dataset['train_input']);
model.plot(beta=100)

# %% [markdown]
# 5. Train the KAN

# %%
# Train the model
model.train(dataset, opt="LBFGS", steps=20, lamb=0.01, lamb_entropy=10.);
# Out:
# train loss: 1.24e-01 | test loss: 1.31e-01 | reg: 2.71e+01 : 100%|██| 20/20 [00:12<00:00,  1.60it/s]

# %% [markdown]
# 6. Plot the trained KAN

# %%
model.plot()
